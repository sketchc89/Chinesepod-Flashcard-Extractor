# %%
from bs4 import BeautifulSoup

# %%
with open('/home/sketchc89/Downloads/newbie.html') as f:
    soup = BeautifulSoup(f, 'html.parser')
    for link in soup.find_all('a'):
        if 'lesson' in link.get('href'):
            print(link.get('href'))
# Out:
# https://chinesepod.com/lessons/number-0-to-10000-and-beyond
# https://chinesepod.com/lessons/chinese-idioms-lower-than-a-pig-or-dog
# https://chinesepod.com/lessons/chinese-idioms-spiderwebs-and-horse-tracks
# https://chinesepod.com/lessons/4-tones-of-zhu
# https://chinesepod.com/lessons/do-you-have-wifi
# https://chinesepod.com/lessons/counting-to-10
# https://chinesepod.com/lessons/the-characters-of-ma
# https://chinesepod.com/lessons/the-tones-of-ma
# https://chinesepod.com/lessons/the-5-w-questions
# https://chinesepod.com/lessons/more-measure-words-%E6%9B%B4%E5%A4%9A%E9%87%8F%E8%AF%8D-atwti-30
# https://chinesepod.com/lessons/introducing-measure-words-%E5%9F%BA%E6%9C%AC%E9%87%8F%E8%AF%8D-atwti-29
# https://chinesepod.com/lessons/using-can-%E4%BC%9A%E3%80%81%E8%83%BD%E3%80%81%E5%8F%AF%E4%BB%A5-atwti-28
# https://chinesepod.com/lessons/asking-prices-in-chinese-with-%E5%A4%9A%E5%B0%91-atwti-27
# ...
